# %% [markdown]
# # Enzyme Module Extraction For Sabio-RK Database

# %%
# installs the necessary package to run the automation
# https://github.com/helium/helium-python

from helium import *

import pandas as pd

from time import sleep

# %%
# Excel file with the UniProt_IDs of the enzymes that are to be extracted from Sabio-RK 
# Make sure the file name matches and is in the same file path as this notebook
ID_table = pd.read_excel("EnzymeModulesList.xlsx", sep='|')
ID_table
# Out:
#                                       Enzymes UniProt_ID
# 0               Fructose-bisphosphatase (FBP)     P19112
# 1  Glycogen synthase (ggn -> glygn1) (GLGNS1)     P67999

# %%
list_of_ids = []
list_of_urls = []

n = len(ID_table.UniProt_ID)

# Loop that goes through each enzyme using it's ID one by one
for i in range(n):
    ids = ID_table.loc[i, 'UniProt_ID']
    url = 'http://sabiork.h-its.org/newSearch?q=UniProtKB_AC:'+ str(ids)
    
# Opens the url mentioned above into Chrome browser (these browsers can be changed... look at documentation)
    browser = start_chrome(url)
    click(CheckBox("Mutant"))

# Makes sure all of the entries are displayed 
    entries = Text(to_right_of="Total number of kinetic law entries found:").value
    if int(entries) > 15:
        select(ComboBox("15"), "100")
        
    
    
#Loop that checks if total number of kinetic entries that are found are all accounted for (if more than 100)
    left_over = int(entries) - 100
    while (left_over > 0):
        click(CheckBox(below = "Add to export cart?"))
        click("Next")
        left_over = left_over - 100

# Adds the entries on the last page to the cart
    click(CheckBox(below = "Add to export cart?"))


# Automation to export the datasheets as .tsv
    click("Entries to export")
    click(Button("write spreadsheet"))
    click("Add all")

# makes sure there are no repeats in the data sets
    click(CheckBox("Export Distinct Rows Only"))

# This line of code can be changed to export a excel file using the ID name
    click(S("#csvExport"))

    sleep(10)
    kill_browser()

# This creates a list of the IDs and the urls that come out from the excel sheet that was inputted
    list_of_ids =  list_of_ids+[str(ids)]
    list_of_urls = list_of_urls + [url]

# %%
print(list_of_ids)
print(list_of_urls)
# Out:
# ['P19112', 'P67999']
# ['http://sabiork.h-its.org/newSearch?q=UniProtKB_AC:P19112', 'http://sabiork.h-its.org/newSearch?q=UniProtKB_AC:P67999']

# %% [markdown]
# ## Putting the excel files into Pandas Dataframes for Manipulation

# %%
## Combining Dataframes for Enzymes
import pandas as pd
n = len(ID_table.UniProt_ID)

df = pd.read_csv("sabioExport.tsv", sep='\t')

for i in range(n):
    if i == 0:
        df = df.append(pd.read_csv("sabioExport.tsv", sep='\t'))
    else:
        df = df.append(pd.read_csv("sabioExport ("+str(i)+").tsv", sep='\t'))
    
df
# Out:
#     EntryID                                           Reaction  \
# 0       196  H2O + D-Fructose 1,6-bisphosphate = Phosphate ...
# 1       196  H2O + D-Fructose 1,6-bisphosphate = Phosphate ...
# 2       201  H2O + D-Fructose 1,6-bisphosphate = Phosphate ...
# 3       201  H2O + D-Fructose 1,6-bisphosphate = Phosphate ...
# 4       201  H2O + D-Fructose 1,6-bisphosphate = Phosphate ...
# ..      ...                                                ...
# 7     53378  ATP + Arg-Pro-Arg-Thr-Ser-Ser-Phe = ADP + Arg-...
# 8     53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
# 9     53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
# 10    53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
# 11    53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
#
#                                                Buffer  ECNumber  \
# 0   [ 50 mM HEPES, 10 mM Sodium phosphate, 10 mM M...  3.1.3.11
# 1   [ 50 mM HEPES, 10 mM Sodium phosphate, 10 mM M...  3.1.3.11
# 2   [ 50 mM HEPES, 10 mM Sodium phosphate, 10 mM M...  3.1.3.11
# 3   [ 50 mM HEPES, 10 mM Sodium phosphate, 10 mM M...  3.1.3.11
# 4   [ 50 mM HEPES, 10 mM Sodium phosphate, 10 mM M...  3.1.3.11
# ..                                                ...       ...
# 7   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
# 8   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
# 9   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
# 10  [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
# 11  [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#
#                                      CellularLocation   UniProtKB_AC  Tissue  \
# 0       [unknown, unknown, unknown, unknown, unknown]  Q9Z1N1;P19112  kidney
# 1       [unknown, unknown, unknown, unknown, unknown]  Q9Z1N1;P19112  kidney
# 2   [unknown, unknown, unknown, unknown, unknown, ...  Q9Z1N1;P19112  kidney
# 3   [unknown, unknown, unknown, unknown, unknown, ...  Q9Z1N1;P19112  kidney
# 4   [unknown, unknown, unknown, unknown, unknown, ...  Q9Z1N1;P19112  kidney
# ..                                                ...            ...     ...
# 7       [unknown, unknown, unknown, unknown, unknown]         P67999   liver
# 8       [unknown, unknown, unknown, unknown, unknown]         P67999   liver
# 9       [unknown, unknown, unknown, unknown, unknown]         P67999   liver
# 10      [unknown, unknown, unknown, unknown, unknown]         P67999   liver
# 11      [unknown, unknown, unknown, unknown, unknown]         P67999   liver
#
#    Enzyme Variant                                    Enzymename  \
# 0        wildtype                       fructose-bisphosphatase
# 1        wildtype                       fructose-bisphosphatase
# 2        wildtype                       fructose-bisphosphatase
# 3        wildtype                       fructose-bisphosphatase
# 4        wildtype                       fructose-bisphosphatase
# ..            ...                                           ...
# 7        wildtype  non-specific serine/threonine protein kinase
# 8        wildtype  non-specific serine/threonine protein kinase
# 9        wildtype  non-specific serine/threonine protein kinase
# 10       wildtype  non-specific serine/threonine protein kinase
# 11       wildtype  non-specific serine/threonine protein kinase
#
#              Organism  ...  parameter.endValue  parameter.standardDeviation  \
# 0   Rattus norvegicus  ...                 NaN                       6.0E-7
# 1   Rattus norvegicus  ...                 NaN                            -
# 2   Rattus norvegicus  ...                 NaN                       9.0E-7
# 3   Rattus norvegicus  ...             0.00005                          NaN
# 4   Rattus norvegicus  ...                 NaN                   1.33333E-7
# ..                ...  ...                 ...                          ...
# 7   Rattus norvegicus  ...                 NaN                            -
# 8   Rattus norvegicus  ...                 NaN                            -
# 9   Rattus norvegicus  ...                 NaN                            -
# 10  Rattus norvegicus  ...                 NaN                            -
# 11  Rattus norvegicus  ...                 NaN                            -
#
#        parameter.unit       Pathway  \
# 0                   M  Calvin cycle
# 1     M*s^(-1)*g^(-1)  Calvin cycle
# 2                   M  Calvin cycle
# 3                   M  Calvin cycle
# 4     M*s^(-1)*g^(-1)  Calvin cycle
# ..                ...           ...
# 7                   M           NaN
# 8                   M           NaN
# 9                   M           NaN
# 10                  -           NaN
# 11  mol*s^(-1)*g^(-1)           NaN
#
#                                       Product PubMedID  \
# 0            Phosphate;D-Fructose 6-phosphate  8396135
# 1            Phosphate;D-Fructose 6-phosphate  8396135
# 2            Phosphate;D-Fructose 6-phosphate  8396135
# 3            Phosphate;D-Fructose 6-phosphate  8396135
# 4            Phosphate;D-Fructose 6-phosphate  8396135
# ..                                        ...      ...
# 7   ADP;Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe  8985174
# 8   ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe  8985174
# 9   ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe  8985174
# 10  ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe  8985174
# 11  ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe  8985174
#
#                                           Publication  Rate Equation  \
# 0   Sola MM, Salto R, Oliver FJ, Gutiérrez M, Varg...        unknown
# 1   Sola MM, Salto R, Oliver FJ, Gutiérrez M, Varg...        unknown
# 2   Sola MM, Salto R, Oliver FJ, Gutiérrez M, Varg...        unknown
# 3   Sola MM, Salto R, Oliver FJ, Gutiérrez M, Varg...        unknown
# 4   Sola MM, Salto R, Oliver FJ, Gutiérrez M, Varg...        unknown
# ..                                                ...            ...
# 7   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
# 8   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
# 9   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
# 10  Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
# 11  Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#
#    SabioReactionID                        Substrate
# 0             1117  H2O;D-Fructose 1,6-bisphosphate
# 1             1117  H2O;D-Fructose 1,6-bisphosphate
# 2             1117  D-Fructose 1,6-bisphosphate;H2O
# 3             1117  D-Fructose 1,6-bisphosphate;H2O
# 4             1117  D-Fructose 1,6-bisphosphate;H2O
# ..             ...                              ...
# 7            13734  ATP;Arg-Pro-Arg-Thr-Ser-Ser-Phe
# 8            13735  ATP;Arg-Pro-Arg-Thr-Ser-Thr-Phe
# 9            13735  ATP;Arg-Pro-Arg-Thr-Ser-Thr-Phe
# 10           13735  ATP;Arg-Pro-Arg-Thr-Ser-Thr-Phe
# 11           13735                         ATP;Arg-
#
# [114 rows x 31 columns]

# %%
## Output Dataframe for Enzymes Separately
import pandas as pd

dataframe_list=[]

for i in range(n):
    if i == 0:
        pd.read_csv("sabioExport.tsv", sep='\t')
    else:
        dataframe_list = dataframe_list+ [pd.read_csv("sabioExport ("+str(i)+").tsv", sep='\t')]

dataframe_list
# Out:
# [    EntryID                                           Reaction  \
#  0     53377  ATP + Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-...
#  1     53377  ATP + Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-...
#  2     53377  ATP + Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-...
#  3     53377  ATP + Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-...
#  4     53378  ATP + Arg-Pro-Arg-Thr-Ser-Ser-Phe = ADP + Arg-...
#  5     53378  ATP + Arg-Pro-Arg-Thr-Ser-Ser-Phe = ADP + Arg-...
#  6     53378  ATP + Arg-Pro-Arg-Thr-Ser-Ser-Phe = ADP + Arg-...
#  7     53378  ATP + Arg-Pro-Arg-Thr-Ser-Ser-Phe = ADP + Arg-...
#  8     53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
#  9     53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
#  10    53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
#  11    53379  ATP + Arg-Pro-Arg-Thr-Ser-Thr-Phe = ADP + Arg-...
#
#                                                 Buffer  ECNumber  \
#  0   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  1   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  2   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  3   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  4   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  5   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  6   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  7   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  8   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  9   [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  10  [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#  11  [50 mM Tris-HCl, 0.1 mM EGTA, 0.1 % (v/v) 2-me...  2.7.11.1
#
#                                   CellularLocation UniProtKB_AC Tissue  \
#  0   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  1   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  2   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  3   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  4   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  5   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  6   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  7   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  8   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  9   [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  10  [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#  11  [unknown, unknown, unknown, unknown, unknown]       P67999  liver
#
#     Enzyme Variant                                    Enzymename  \
#  0        wildtype  non-specific serine/threonine protein kinase
#  1        wildtype  non-specific serine/threonine protein kinase
#  2        wildtype  non-specific serine/threonine protein kinase
#  3        wildtype  non-specific serine/threonine protein kinase
#  4        wildtype  non-specific serine/threonine protein kinase
#  5        wildtype  non-specific serine/threonine protein kinase
#  6        wildtype  non-specific serine/threonine protein kinase
#  7        wildtype  non-specific serine/threonine protein kinase
#  8        wildtype  non-specific serine/threonine protein kinase
#  9        wildtype  non-specific serine/threonine protein kinase
#  10       wildtype  non-specific serine/threonine protein kinase
#  11       wildtype  non-specific serine/threonine protein kinase
#
#               Organism  ...  parameter.endValue  parameter.standardDeviation  \
#  0   Rattus norvegicus  ...             0.00003                            -
#  1   Rattus norvegicus  ...                 NaN                            -
#  2   Rattus norvegicus  ...                 NaN                            -
#  3   Rattus norvegicus  ...                 NaN                            -
#  4   Rattus norvegicus  ...                 NaN                            -
#  5   Rattus norvegicus  ...                 NaN                            -
#  6   Rattus norvegicus  ...                 NaN                            -
#  7   Rattus norvegicus  ...                 NaN                            -
#  8   Rattus norvegicus  ...                 NaN                            -
#  9   Rattus norvegicus  ...                 NaN                            -
#  10  Rattus norvegicus  ...                 NaN                            -
#  11  Rattus norvegicus  ...                 NaN                            -
#
#         parameter.unit  Pathway  \
#  0                   M      NaN
#  1                   M      NaN
#  2   mol*s^(-1)*g^(-1)      NaN
#  3                   M      NaN
#  4                   -      NaN
#  5   mol*s^(-1)*g^(-1)      NaN
#  6                   M      NaN
#  7                   M      NaN
#  8                   M      NaN
#  9                   M      NaN
#  10                  -      NaN
#  11  mol*s^(-1)*g^(-1)      NaN
#
#                                                Product  PubMedID  \
#  0   ADP;Gly-Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe-...   8985174
#  1   ADP;Gly-Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe-...   8985174
#  2   ADP;Gly-Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe-...   8985174
#  3   ADP;Gly-Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe-...   8985174
#  4           ADP;Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe   8985174
#  5           ADP;Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe   8985174
#  6           ADP;Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe   8985174
#  7           ADP;Arg-Pro-Arg-Thr-Ser-Ser-phosphate-Phe   8985174
#  8           ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe   8985174
#  9           ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe   8985174
#  10          ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe   8985174
#  11          ADP;Arg-Pro-Arg-Thr-Ser-Thr-phosphate-Phe   8985174
#
#                                            Publication  Rate Equation  \
#  0   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  1   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  2   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  3   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  4   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  5   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  6   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  7   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  8   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  9   Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  10  Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#  11  Alessi DR, Caudwell FB, Andjelkovic M, Hemming...  Vmax*S/(Km+S)
#
#     SabioReactionID                                        Substrate
#  0            13731  Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-Gly;ATP
#  1            13731  Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-Gly;ATP
#  2            13731  Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-Gly;ATP
#  3            13731  Gly-Arg-Pro-Arg-Thr-Ser-Ser-Phe-Ala-Glu-Gly;ATP
#  4            13734                  ATP;Arg-Pro-Arg-Thr-Ser-Ser-Phe
#  5            13734                  ATP;Arg-Pro-Arg-Thr-Ser-Ser-Phe
#  6            13734                  ATP;Arg-Pro-Arg-Thr-Ser-Ser-Phe
#  7            13734                  ATP;Arg-Pro-Arg-Thr-Ser-Ser-Phe
#  8            13735                  ATP;Arg-Pro-Arg-Thr-Ser-Thr-Phe
#  9            13735                  ATP;Arg-Pro-Arg-Thr-Ser-Thr-Phe
#  10           13735                  ATP;Arg-Pro-Arg-Thr-Ser-Thr-Phe
#  11           13735                                         ATP;Arg-
#
#  [12 rows x 31 columns]]

# %% [markdown]
# ### Extra Note:
#
# Sometimes the "Entries to export" doesn't take in all of the entries (especially if number of entries are over 200)
#
# (Here is the code that we tried for that section, it would go in the for loop that goes through all of the UniprotIDs)
#
# <code>if (entries == Text(to_left_of = Image(alt="show selected Entries")).value):
#     print("you are all good")
# else:
#     print("you might need to redo this")
# </code>
